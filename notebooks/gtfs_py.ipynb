# %%
# %pip install gtfspy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.2/272.2 KB 5.2 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 KB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 KB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.9 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 51.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 KB 38.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [248 lines of output]
# ...

# %%
import os

from gtfspy import import_gtfs
from gtfspy import gtfs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/jovyan/work/transit/notebooks/gtfs_py.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell://code.v2202103143410146133.quicksrv.de/home/jovyan/work/transit/notebooks/gtfs_py.ipynb#ch0000001vscode-remote?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell://code.v2202103143410146133.quicksrv.de/home/jovyan/work/transit/notebooks/gtfs_py.ipynb#ch0000001vscode-remote?line=2'>3</a> from gtfspy import import_gtfs
#       <a href='vscode-notebook-cell://code.v2202103143410146133.quicksrv.de/home/jovyan/work/transit/notebooks/gtfs_py.ipynb#ch0000001vscode-remote?line=3'>4</a> from gtfspy import gtfs
#
# File /opt/conda/envs/myenv/lib/python3.9/site-packages/gtfspy/import_gtfs.py:7, in <module>
# ...
